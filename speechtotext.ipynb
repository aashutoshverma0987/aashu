# %% [markdown]
# <a href="https://colab.research.google.com/github/aashutoshverma0987/aashu/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create text from audio using whisper model
! pip install openai-whisper
! apt install ffmpeg

#to convert  the audio into text
import whisper

#to select the audio file from system
from google.colab import files

#to load the model using whisper
model = whisper.load_model("base")
uploaded = files.upload
audio_files =list (uploaded.keys())[0]
result = model.transcribe(audio_files)
print(result["text"])
